# %% [markdown]
# <a href="https://colab.research.google.com/github/missakaherath/RoBERTaABSA/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/missakaherath/RoBERTaABSA/
# Out:
# Cloning into 'RoBERTaABSA'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 150 (delta 40), reused 132 (delta 25), pack-reused 0
# Receiving objects: 100% (150/150), 4.40 MiB | 21.25 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
# !pip install fastNLP fitlog

# %%
# %cd /content/RoBERTaABSA/Train
# Out:
# /content/RoBERTaABSA/Train

# %%
# !pip install -U git+https://github.com/Adapter-Hub/adapter-transformers.git
# Out:
# ...
#   Cloning https://github.com/Adapter-Hub/adapter-transformers.git to /tmp/pip-req-build-85__wvlw
#   Running command git clone -q https://github.com/Adapter-Hub/adapter-transformers.git /tmp/pip-req-build-85__wvlw
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 596 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 895 kB 36.7 MB/s
# ...
#      |████████████████████████████████| 61 kB 405 kB/s
# ...
#      |████████████████████████████████| 3.3 MB 41.3 MB/s
# ...
#   Created wheel for adapter-transformers: filename=adapter_transformers-2.3.0a0-py3-none-any.whl size=3126695 sha256=0a0d83018828455ec2adb262ead88f5c2b5ed11541e28a9ca605451ca6c292a9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-idzc_ea3/wheels/60/0e/d5/86e64fef3085f149b504f48af9ca6e8f6da427f42da9b4bbe5
# Successfully built adapter-transformers
# ...
#   Attempting uninstall: pyyaml
# ...

# %%
# !pip install -U adapter-transformers
# !pip install datasets
# !pip install SentencePiece
# !pip install torch==1.5.1
# Out:
# ...
#      |████████████████████████████████| 298 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 41.0 MB/s
# ...
#      |████████████████████████████████| 132 kB 68.4 MB/s
# ...
#      |████████████████████████████████| 243 kB 71.4 MB/s
# ...
#      |████████████████████████████████| 160 kB 47.2 MB/s
# ...
#      |████████████████████████████████| 271 kB 51.4 MB/s
# ...
#      |████████████████████████████████| 192 kB 70.6 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 753.2 MB 12 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.11.1+cu111 requires torch==1.10.0, but you have torch 1.5.1 which is incompatible.
# ...

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.5 MB 21.9 MB/s
# ...
#      |████████████████████████████████| 895 kB 61.8 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 62.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 64.9 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !CUDA_LAUNCH_BLOCKING=1 python finetune.py --model_name roberta-en --data_dir /content/RoBERTaABSA/Dataset --dataset Restaurants
# Out:
# Namespace(batch_size=32, data_dir='/content/RoBERTaABSA/Dataset', dataset='Restaurants', lr=2e-05, model_name='roberta-en', save_embed=1)
# http://download.fastnlp.top/embedding/roberta-base.zip not found in cache, downloading to /tmp/tmpmnfn29vz
# 100% 297M/297M [01:17<00:00, 3.83MB/s]
# Finish download from http://download.fastnlp.top/embedding/roberta-base.zip
# Copy file to /root/.fastNLP/embedding/roberta-base
# Save cache to ./caches/data_Restaurants_<mask>_roberta-en.pkl.
# In total 2 datasets:
# 	test has 1120 instances.
# 	train has 3608 instances.
# In total 1 vocabs:
# 	target has 4 entries.
#
# Load pre-trained RoBERTa parameters from file /root/.fastNLP/embedding/roberta-base/pytorch_model.bin.
# training epochs started 2022-02-10-04-52-10-923693
# [epoch:   1 step:    5] train loss: 1.04574 time: 0:00:02
# [epoch:   1 step:   10] train loss: 1.06318 time: 0:00:04
# [epoch:   1 step:   15] train loss: 1.03473 time: 0:00:06
# ...
